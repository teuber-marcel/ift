# %%
import opt

# %%
opt.find_hyperparams(dir_img='Experiments/tune/img/', dir_lab='Experiments/tune/gt/', dir_seeds='Experiments/tune/seeds-1/',
                     dir_out='Experiments/tune/out/', dir_out_best='Experiments/tune/out-best/', max_bopt_iter=50)
# Out:
# Iteration 1 of Bayesian Optimisation
# Trying
# Height: 0
# Learning rate: 0.0005683105756945855
# Min. tree size: 700
# # targets: 82
# # impostors: 57
#
# Evaluation error=0.1922
#
# Iteration 2 of Bayesian Optimisation
# Trying
# Height: 0
# Learning rate: 0.0005761882690235895
# Min. tree size: 551
# # targets: 69
# # impostors: 145
#
# Evaluation error=0.2059
#
# Iteration 3 of Bayesian Optimisation
# Trying
# Height: 10
# Learning rate: 4.27975377864891e-05
# Min. tree size: 381
# # targets: 61
# # impostors: 53
#
# Evaluation error=0.2678
#
# Iteration 4 of Bayesian Optimisation
# Trying
# Height: 0
# Learning rate: 0.0004639199140223995
# Min. tree size: 575
# # targets: 148
# # impostors: 102
#
# Evaluation error=0.2023
#
# Iteration 5 of Bayesian Optimisation
# Trying
# Height: 10
# Learning rate: 0.0006053800241478974
# Min. tree size: 796
# # targets: 115
# # impostors: 21
#
# Evaluation error=0.3097
#
# ...
