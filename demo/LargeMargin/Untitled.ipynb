# %%
import numpy as np
import plots
import matplotlib.pyplot as plt

plt.style.use('ggplot')

# %%
ary = np.genfromtxt('init-active-seeds.csv', delimiter=',')
X = ary[:, 0:-1]
y = ary[:, -1].astype(np.int32)
L = np.genfromtxt('init-transform.csv', delimiter=',')

plots.plot_comparison(L, X, y, dim_pref=3)
L
# Out:
# array([[ 0.080309,  0.841968, -0.262168],
#        [ 0.841968, -0.054945,  0.230272],
#        [-0.262168,  0.230272,  1.302281]])

# %%
ary = np.genfromtxt('init-active-seeds.csv', delimiter=',')
X = ary[:, 0:-1]
y = ary[:, -1].astype(np.int32)
L = np.genfromtxt('transform.csv', delimiter=',')

plots.plot_comparison(L, X, y, dim_pref=3)
L
# Out:
# array([[ 0.080309,  0.841968, -0.262168],
#        [ 0.841968, -0.054945,  0.230272],
#        [-0.262168,  0.230272,  1.302281]])

# %%
ary = np.genfromtxt('active-seeds.csv', delimiter=',')
X = ary[:, 0:-1]
y = ary[:, -1].astype(np.int32)
L = np.genfromtxt('transform.csv', delimiter=',')

plots.plot_comparison(L, X, y, dim_pref=3)
L
# Out:
# array([[ 0.080309,  0.841968, -0.262168],
#        [ 0.841968, -0.054945,  0.230272],
#        [-0.262168,  0.230272,  1.302281]])
